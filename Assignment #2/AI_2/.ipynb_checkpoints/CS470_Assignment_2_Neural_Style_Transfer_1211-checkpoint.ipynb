# %% [markdown]
# # CS470 Assignment #2: Neural Style Transfer
#
# Primary TA: Hyunsu Kim
#
# TA's E-mail: khszone02@kaist.ac.kr
#
# ## Instruction
# - There are total **two models** for the neural style transfer in this homework.
# - Fill in the code blocks enveloped with some comments
# - Refer to [the neural style transfer paper](https://arxiv.org/pdf/1508.06576.pdf) or the lecture slide for the first neural style transfer model.
# - Refer to [the fast neural style transfer paper](https://cs.stanford.edu/people/jcjohns/papers/eccv16/JohnsonECCV16.pdf) or the lecture slide for the second neural style transfer model.
# - There are total **10 problems**. Only the last problem (10) is for the second model. You have to start the **problem 10** as soon as possible if you want to get a score for the second model (20%). **It will take lots of time** in aspects of both coding and learning times.
#
# ## Submission guidelines
# - *(The first and second model)* **Don't revise the codes except the commented blocks when you submit this notebook.**
# - *(The second model)* The TAs should be able to reproduce your results using your code and pre-trained model. **Please double-check if your code runs without error and loads your pre-trained model properly.** Submissions failed to run or reproduce the results will get a substantial penalty.
#
# ## Deliverables
# - Download your **Notebook file (*for the first and second model*)**, **style/content/synthsized images (*for the first and second model*)**, and the **checkpoints (*only for the second model*)**, and submit a zip file in a format: [StudentID].zip. Please double-check that you locate and load your pre-trained model (checkpoints) properly.
# - Your assignment should be submitted through **KLMS**. All other submissions (e.g., via email) will not be considered as valid submissions.
#
# ## Grading policy
# - **Code** (100%): The filled code blocks should work well. **Each problem occupies some points** so that you get a score if you write appropriate code logic even though the model doesn't work.
#   - **The first model** (80%): Step 1-8
#   - **The second model** (20%): Step 9 (will be taken lots of time)
# - **Result** (Extra points): Extra points will be given if you generated a **naturally** synthesized image. If you generate an awful image such as so noisy image, an image that the style is not similar to the style image and so on. You should tune the hyperparameters to improve the image quality.
#
# ## Due date
# Midnight October 30
#
# ## Questions
# - Please use QnA board in KLMS as a main communication channel. When you post questions, please make it public so that all students can share the information. Please use the prefix "[Assignment 2]" in the subject for all questions regarding this assignment (e.g., [Assignment 2] Regarding the grading policy).
#
# ## PyTorch Documentation
# - You can refer PyTorch documentation for your assignment.
# - https://pytorch.org/docs/stable/index.html

# %% [markdown]
# ## Step 0: Connect to Google drive

# %%
from google.colab import drive

drive.mount('/gdrive')
gdrive_root = '/gdrive/My Drive'
gdrive_data = '/gdrive/My Drive/my_data'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# ## Step 1: Import modules

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt

import torchvision.transforms as transforms  # transform PIL images into tensors
import torchvision.models as models  # train or load pre-trained models
from torchvision import datasets

import copy

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Step 2: Download images
# Now we will import the style and content images. The original PIL images have values between 0 and 255, but when transformed into torch tensors, their values are converted to be between 0 and 1. The images also need to be resized to have the same dimensions.
#
# **Problem 1.** Pick images to merge. The style image should be an western painting (no margin).

# %%
import urllib

##########################################################################
#### TODO: Download images to merge.                                  ####
####       The style image should be an western painting (no margin). ####
##########################################################################

# revise only image URLs
#urllib.request.urlretrieve("https://www.pablopicasso.org/images/paintings/accordionist.jpg", "style.jpg")
#urllib.request.urlretrieve("https://cdn.images.express.co.uk/img/dynamic/36/590x/Joaquin-Phoenix-as-Joker-in-new-DC-movie-Joker-1185726.jpg?r=1570557109810", "content.jpg")

# Needs further study...? style images that I just couldn't get the style transfer to work...
#urllib.request.urlretrieve("https://www.jackson-pollock.org/images/paintings/convergence.jpg", "style.jpg")
#urllib.request.urlretrieve("https://uploads6.wikiart.org/images/andy-warhol/mao-2.jpg!Large.jpg", "style.jpg")
#urllib.request.urlretrieve("https://blog.orangecarton.com/wp-content/uploads/2013/05/modernism.jpg", "style.jpg")\
#urllib.request.urlretrieve("https://blog.orangecarton.com/wp-content/uploads/2013/05/modernism1.jpg", "style.jpg")


urllib.request.urlretrieve("https://blog.orangecarton.com/wp-content/uploads/2013/05/the_scream.jpg", "style.jpg")
#urllib.request.urlretrieve("https://blog.orangecarton.com/wp-content/uploads/2013/05/impressionism.jpg", "style.jpg")
#urllib.request.urlretrieve("https://www.artistsnetwork.com/store/media/catalog/product/cache/2/thumbnail/600x/17f82f742ffe127f42dca9de82fb58b1/z/e/zeiezkxc9z02tkqddjku.png", "style.jpg")


urllib.request.urlretrieve("http://times.postech.ac.kr/news/photo/201702/9551_24543_717.png", "content.jpg")
#urllib.request.urlretrieve("http://www.futurekorea.co.kr/news/photo/201612/35542_28108_89.jpg", "content.jpg")
#urllib.request.urlretrieve("https://i.gyazo.com/b72217e040e4a6d9a2448bb09e9751b5.jpg", "content.jpg")
##########################################################################

# !ls style.jpg content.jpg
# Out:
# content.jpg  style.jpg

# %%
imsize = 256

preprocess = transforms.Compose([
  transforms.Resize(imsize),            # fixed size for both content and style images
  transforms.CenterCrop(imsize),        # crops the given PIL Image at the center.
  transforms.ToTensor(),                # range between 0 and 1
])

# %%
# A PIL image to a Tensor
def image_loader(image_name, batch_size=None):
  image = Image.open(image_name)
  image = preprocess(image)
  if batch_size is None:
    image = image.unsqueeze(0)      # fake batch dimension for the pre-trained model input.
  else:
    image = image.repeat(batch_size, 1, 1, 1)

  return image.to(device, torch.float)

# %%
# A Tensor to a PIL image
def imshow(tensor, title=None, save=None):
  unloader = transforms.ToPILImage()
  image = tensor.cpu().clone()
  image = image.squeeze(0)
  image = unloader(image)
  plt.imshow(image)
  if title is not None:
    plt.title(title)
  plt.pause(0.001)
  if save:
    image.save(save)

# %%
style_img = image_loader("./style.jpg")
content_img = image_loader("./content.jpg")

plt.ion()

plt.figure()
imshow(style_img, title='Style Image', save=gdrive_data+'/style.jpg')  # save at Google drive my_data directory

plt.figure()
imshow(content_img, title='Content Image', save=gdrive_data+'/content.jpg')

# %% [markdown]
# ## Step 3: Preload the pre-trained model
# Now we need to import a pre-trained neural network. We will use a 19 layer VGG network like the one used in the paper. PyTorch’s implementation of VGG is a module divided into two child Sequential modules: features (containing convolution and pooling layers), and classifier (containing fully connected layers). We will use the features module because we need the output of the individual convolution layers to measure content and style loss. Some layers have different behavior during training than evaluation, so we must set the network to evaluation mode using .eval().

# %%
cnn = models.vgg19(pretrained=True).features.to(device).eval()

#print(cnn)

# %% [markdown]
# ## Step 4: Define the loss functions
#
# $$P^* = \underset{P}{\mathrm{argmin}}\ \mathcal{L}_{content}(P, X) + \lambda\mathcal{L}_{style}(P, Y)$$
# P is an input image, X is a content image, and Y is a style image.
# ### Content Loss
# $$\mathcal{L}_{content}(P, X) = \sum_l\sum_{i, j}w_l\biggr(F_{i,j}^{X,l} - F_{i,j}^{P,l}\biggr)^2$$
# l is the layer, F_ij is a ith row and jth column of a feature, and w is a weight.
#
# **Problem 2.** Define the content loss for a layer. Don't regard weights, which is computed inside the optimization.

# %%
class ContentLoss(nn.Module):
  def __init__(self, target):
    super(ContentLoss, self).__init__()
    self.target = target.detach()  # the feature tensor of the content image

  def forward(self, input):
    ################################################################################
    #### TODO: Define the content loss for a layer.                             ####
    ####       Don't regard weights, which is computed inside the optimization. ####
    #### Input:                                                                 ####
    ####   - input: the feature tensors of (a, b, c, d) size, where             ####
    ####            a = batch size (= 1)                                        ####
    ####            b = number of feature maps                                  ####
    ####            (c, d) = dimensions of a feature map (N=c*d)                ####
    #### Output:                                                                ####
    ####   - input                                                              ####
    ################################################################################
#    tensor_loss = torch.sum((input - self.target) ** 2)
#    self.loss = tensor_loss.item()
#    del tensor_loss
    self.loss = F.mse_loss(input, self.target)
    ################################################################################
    return input

# %% [markdown]
# ### Style Loss
# $$\mathcal{L}_{style}(P, Y) = \sum_l\sum_{i, j}w_l\biggr(G_{i,j}^{Y,l} - G_{i,j}^{P,l}\biggr)^2$$
# $$\mathrm{(Gram\ matrix)}\ G = F^TF$$
# l is the layer, G_ij is a ith row and jth column of a gram matrix, and w is a weight.
#
# **Problem 3.** Define the gram matrix.

# %%
def gram_matrix(input):
  ################################################################################
  #### TODO: Define the gram matrix.                                          ####
  #### Input:                                                                 ####
  ####   - input: the feature tensors of (a, b, c, d) size, where             ####
  ####            a = batch size (= 1)                                        ####
  ####            b = number of feature maps                                  ####
  ####            (c, d) = dimensions of a feature map (N=c*d)                ####
  #### Output:                                                                ####
  ####   - G: the gram matrix of (b, b) size                                  ####
  ################################################################################
  a, b, c, d = input.size()

  F = input.view(a  * b, c * d)
  G = torch.mm(F, F.t())
#  G = torch.mm(F.t(), F)
#  del F

#  b = size[1]
#  c = size[2]
#  d = size[3]

#  G = torch.zeros(b, b)

#  for i1 in range(b):
#    for j1 in range(b):
#      for i2 in range(c):
#        for j2 in range(d):
#          f_i1 = input[:, i1, i2, j2].squeeze()
#          f_j1 = input[:, j1, i2, j2].squeeze()
#          G[i1, j1] += (f_i1 * f_j1).squeeze()
  ################################################################################
  return G.div(a * b * c * d)

# %% [markdown]
# **Problem 4.** Define the style loss for a layer with the gram matrix. Don't regard weights, which is computed inside the optimization.

# %%
class StyleLoss(nn.Module):
  def __init__(self, target):
    super(StyleLoss, self).__init__()
    self.target = target.detach()  # the feature tensor of the style image

  def forward(self, input):
    ################################################################################
    #### TODO: Define the style loss for a layer with the gram matrix.          ####
    ####       Don't regard weights, which is computed inside the optimization. ####
    #### Input:                                                                 ####
    ####   - input: the feature tensors of (a, b, c, d) size, where             ####
    ####            a = batch size (= 1)                                        ####
    ####            b = number of feature maps                                  ####
    ####            (c, d) = dimensions of a feature map (N=c*d)                ####
    #### Output:                                                                ####
    ####   - input                                                              ####
    ################################################################################
#    tensor_loss = torch.sum((gram_matrix(input) - gram_matrix(self.target)) ** 2)
#    self.loss = tensor_loss.item()
#    del tensor_loss
    self.loss = F.mse_loss(gram_matrix(input), gram_matrix(self.target))
    ################################################################################
    return input

# %% [markdown]
# ## Step 5: Transfer model
#
# VGG networks are trained on images with each channel normalized by mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225]. We will use them to normalize the image before sending it into the network.

# %%
class NormalizationLayer(nn.Module):
  def __init__(self, mean, std):
    super(NormalizationLayer, self).__init__()
    self.mean = torch.tensor(mean).view(-1, 1, 1)
    self.std = torch.tensor(std).view(-1, 1, 1)

  def forward(self, img):
    return (img - self.mean) / self.std

# %% [markdown]
# A Sequential module contains an ordered list of child modules. For instance, vgg19.features contains a sequence (Conv2d, ReLU, MaxPool2d, Conv2d, ReLU…) aligned in the right order of depth. We need to add our content loss and style loss layers immediately after the convolution layer they are detecting.
#
# **Problem 5.** Decide on which layers to compute the content loss and the style loss.

# %%
######################################################################################
#### TODO: Decide on which layers to compute the content loss and the style loss. ####
######################################################################################

# content_layers = ['conv_[number]']
# style_layers = ['conv_[number]', 'conv_[number]', 'conv_[number]', 'conv_[number]', 'conv_[number]']
content_layers = ['conv_2']
style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']
######################################################################################

# %%
def transfer_model(cnn, style_img, content_img):
  
  # import the pre-trained model
  cnn = copy.deepcopy(cnn)
  
  # initialize the transfer model with a normalization layer first
  normalization_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
  normalization_std = torch.tensor([0.229, 0.224, 0.225]).to(device)
  model = nn.Sequential(NormalizationLayer(normalization_mean, normalization_std).to(device))

  content_losses = []
  style_losses = []
  # stack the cnn layers on the transfer model
  i = 0
  for layer in cnn.children():
    if isinstance(layer, nn.Conv2d):
      i += 1
      name = f"conv_{i}"
    elif isinstance(layer, nn.ReLU):
      name = f"relu_{i}"
      layer = nn.ReLU(inplace=False)
    elif isinstance(layer, nn.MaxPool2d):
      name = f"pool_{i}"
    elif isinstance(layer, nn.BatchNorm2d):
      name = f"bn_{i}"
    else:
      raise RuntimeError(f"Unrecognized layer: {layer.__class__.__name__}")
    
    model.add_module(name, layer)

    if name in content_layers:
      target = model(content_img).detach()
      content_loss = ContentLoss(target)
      model.add_module(f"content_loss_{i}", content_loss)
      content_losses.append(content_loss)
    
    if name in style_layers:
      target_feature = model(style_img).detach()
      style_loss = StyleLoss(target_feature)
      model.add_module(f"style_loss_{i}", style_loss);
      style_losses.append(style_loss)

  for i in range(len(model) - 1, -1, -1):
    if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
      break
      
  model = model[:(i + 1)]

  return model, style_losses, content_losses

# %% [markdown]
# ## Step 6: Define the style transfer
#
# We will use L-BFGS algorithm to run our gradient descent. Unlike training a network, we want to train the input image in order to minimise the content and style losses.

# %%
def get_input_optimizer(input_img):
  optimizer = optim.LBFGS([input_img.requires_grad_()])
  return optimizer

# %% [markdown]
# Finally, we must define a function that performs the neural transfer. For each iteration of the networks, it is fed an updated input and computes new losses. We will run the backward methods of each loss module to dynamicaly compute their gradients. The optimizer requires a “closure” function, which reevaluates the model and returns the loss.
#
# We still have one final constraint to address. The network may try to optimize the input with values that exceed the 0 to 1 tensor range for the image. We can address this by correcting the input values to be between 0 to 1 each time the network is run.

# %%
def merge_image(cnn, content_img, style_img, input_img,
                num_steps, style_weight, content_weight):

  # get a transfer model
  model, style_losses, content_losses = transfer_model(cnn, style_img, content_img)

  # get an optimizer
  output_img = input_img.clone()
  optimizer = get_input_optimizer(output_img)

  # start optimizing
  run = [0]
  while run[0] <= num_steps:
    def closure():
      output_img.data.clamp_(0, 1)

      optimizer.zero_grad()
      model(output_img)
      style_score = 0
      content_score = 0
      for i, sl in enumerate(style_losses):
        style_score += style_weight[i] * sl.loss
      for j, cl in enumerate(content_losses):
        content_score += content_weight[j] * cl.loss

      loss = style_score + content_score
      loss.backward()

      run[0] += 1
      if run[0] % 50 == 0:
        print(f"run {run}:")
        print(f"Style Loss: {style_score.item():4f} Content Loss: {content_score.item():4f}")
        print()

      return style_score + content_score

    optimizer.step(closure)

  output_img.data.clamp_(0, 1)

  del model
  return output_img.cpu()

# %% [markdown]
# ## Step 7: Run the style transfer
# **Problem 6 (Optional).** Revise the hyperparameters if you need.

# %%
###########################################################
#### TODO: Revise the hyperparameters if you need.     ####
###########################################################
#NUM_STEPS = 300
#STYLE_WEIGHTS = [1000000, 1000000, 1000000, 1000000, 1000000]
#CONTENT_WEIGHTS = [1]

NUM_STEPS = 10000
STYLE_WEIGHTS = [1000000, 1000000, 1000000, 1000000, 1000000]
CONTENT_WEIGHTS = [1.1]

assert len(STYLE_WEIGHTS) == len(style_layers) and len(CONTENT_WEIGHTS) == len(content_layers), \
    "we need to set the number of weights equal to the number of the style and content losses"
###########################################################

# %%
input_img = content_img.clone()

plt.figure()
imshow(input_img, title='Input Image')

output_img = merge_image(cnn, content_img, style_img, input_img,
                         NUM_STEPS, STYLE_WEIGHTS, CONTENT_WEIGHTS)

plt.figure()
imshow(output_img, title='Output Image', save=gdrive_data+'/baseline.jpg')

plt.ioff()
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# run [50]:
# Style Loss: 63.645714 Content Loss: 1.818104
#
# run [100]:
# Style Loss: 23.636398 Content Loss: 2.514902
#
# run [150]:
# Style Loss: 11.154140 Content Loss: 2.756586
#
# run [200]:
# Style Loss: 5.342911 Content Loss: 2.890618
#
# run [250]:
# Style Loss: 3.115944 Content Loss: 2.838464
#
# run [300]:
# Style Loss: 1.952999 Content Loss: 2.695697
#
# run [350]:
# Style Loss: 1.242578 Content Loss: 2.568686
#
# run [400]:
# Style Loss: 0.842952 Content Loss: 2.487236
#
# run [450]:
# Style Loss: 0.604797 Content Loss: 2.411078
#
# run [500]:
# Style Loss: 0.475106 Content Loss: 2.347527
#
# run [550]:
# Style Loss: 0.398580 Content Loss: 2.289290
#
# run [600]:
# Style Loss: 0.346742 Content Loss: 2.239315
#
# run [650]:
# Style Loss: 0.312529 Content Loss: 2.195078
#
# run [700]:
# Style Loss: 0.289223 Content Loss: 2.158827
#
# run [750]:
# Style Loss: 0.271599 Content Loss: 2.127595
#
# run [800]:
# Style Loss: 0.259793 Content Loss: 2.099797
#
# run [850]:
# Style Loss: 0.248224 Content Loss: 2.076999
#
# run [900]:
# Style Loss: 0.240309 Content Loss: 2.057169
#
# run [950]:
# Style Loss: 0.232798 Content Loss: 2.041229
#
# run [1000]:
# Style Loss: 0.227519 Content Loss: 2.026492
#
# run [1050]:
# Style Loss: 0.223576 Content Loss: 2.013413
#
# run [1100]:
# Style Loss: 0.219814 Content Loss: 2.002460
#
# run [1150]:
# Style Loss: 0.216771 Content Loss: 1.992673
#
# run [1200]:
# Style Loss: 0.214215 Content Loss: 1.983253
#
# run [1250]:
# Style Loss: 0.212532 Content Loss: 1.975644
#
# run [1300]:
# Style Loss: 0.210337 Content Loss: 1.969085
#
# run [1350]:
# Style Loss: 0.209251 Content Loss: 1.962364
#
# run [1400]:
# Style Loss: 0.207525 Content Loss: 1.957168
#
# run [1450]:
# Style Loss: 0.206391 Content Loss: 1.952125
#
# run [1500]:
# Style Loss: 0.204575 Content Loss: 1.948291
#
# run [1550]:
# Style Loss: 0.204028 Content Loss: 1.943746
#
# run [1600]:
# Style Loss: 0.203005 Content Loss: 1.939903
#
# run [1650]:
# Style Loss: 0.202712 Content Loss: 1.936420
#
# run [1700]:
# Style Loss: 0.202875 Content Loss: 1.932826
#
# run [1750]:
# Style Loss: 0.210866 Content Loss: 1.928935
#
# run [1800]:
# Style Loss: 0.203776 Content Loss: 1.926885
#
# run [1850]:
# Style Loss: 0.203408 Content Loss: 1.924531
#
# run [1900]:
# Style Loss: 0.200168 Content Loss: 1.922023
#
# run [1950]:
# Style Loss: 0.199919 Content Loss: 1.919685
#
# run [2000]:
# Style Loss: 0.199490 Content Loss: 1.917105
#
# run [2050]:
# Style Loss: 0.200082 Content Loss: 1.915792
#
# run [2100]:
# Style Loss: 0.199081 Content Loss: 1.913311
#
# run [2150]:
# Style Loss: 0.202046 Content Loss: 1.912160
#
# run [2200]:
# Style Loss: 0.201413 Content Loss: 1.909723
#
# run [2250]:
# Style Loss: 0.201654 Content Loss: 1.908291
#
# run [2300]:
# Style Loss: 0.202336 Content Loss: 1.907459
#
# run [2350]:
# Style Loss: 2.811690 Content Loss: 1.917569
#
# run [2400]:
# Style Loss: 21320924.000000 Content Loss: 99.421715
#
# run [2450]:
# Style Loss: 13595569.000000 Content Loss: 72.642799
#
# run [2500]:
# Style Loss: 221.919174 Content Loss: 5.767323
#
# run [2550]:
# Style Loss: 55.740894 Content Loss: 5.810171
#
# run [2600]:
# Style Loss: 26.187342 Content Loss: 5.656700
#
# run [2650]:
# Style Loss: 14.828611 Content Loss: 5.480317
#
# run [2700]:
# Style Loss: 8.316107 Content Loss: 5.301420
#
# run [2750]:
# Style Loss: 4.792855 Content Loss: 5.077082
#
# run [2800]:
# Style Loss: 2.782001 Content Loss: 4.849580
#
# run [2850]:
# Style Loss: 1.663605 Content Loss: 4.613127
#
# run [2900]:
# Style Loss: 1.198897 Content Loss: 4.346687
#
# run [2950]:
# Style Loss: 0.805211 Content Loss: 4.114902
#
# run [3000]:
# Style Loss: 0.641239 Content Loss: 3.893844
#
# run [3050]:
# Style Loss: 0.551352 Content Loss: 3.695789
#
# run [3100]:
# Style Loss: 0.465190 Content Loss: 3.534455
#
# run [3150]:
# Style Loss: 0.419331 Content Loss: 3.398777
#
# run [3200]:
# Style Loss: 0.380905 Content Loss: 3.284989
#
# run [3250]:
# Style Loss: 0.351670 Content Loss: 3.187570
#
# run [3300]:
# Style Loss: 0.331016 Content Loss: 3.098994
#
# run [3350]:
# Style Loss: 0.310013 Content Loss: 3.025117
#
# run [3400]:
# Style Loss: 0.294225 Content Loss: 2.957139
#
# run [3450]:
# Style Loss: 0.281200 Content Loss: 2.897425
#
# run [3500]:
# Style Loss: 0.273702 Content Loss: 2.839953
#
# run [3550]:
# Style Loss: 0.268096 Content Loss: 2.787549
#
# run [3600]:
# Style Loss: 0.255910 Content Loss: 2.743259
#
# run [3650]:
# Style Loss: 0.252631 Content Loss: 2.697690
#
# run [3700]:
# Style Loss: 0.249007 Content Loss: 2.654380
#
# run [3750]:
# Style Loss: 0.243122 Content Loss: 2.616948
#
# run [3800]:
# Style Loss: 0.237300 Content Loss: 2.580832
#
# run [3850]:
# Style Loss: 0.233652 Content Loss: 2.545760
#
# run [3900]:
# Style Loss: 0.231671 Content Loss: 2.510901
#
# run [3950]:
# Style Loss: 0.229657 Content Loss: 2.478176
#
# run [4000]:
# Style Loss: 0.226684 Content Loss: 2.447572
#
# run [4050]:
# Style Loss: 0.225614 Content Loss: 2.418618
#
# run [4100]:
# Style Loss: 0.223182 Content Loss: 2.390219
#
# run [4150]:
# Style Loss: 0.221214 Content Loss: 2.364529
#
# run [4200]:
# Style Loss: 0.220693 Content Loss: 2.339421
#
# run [4250]:
# Style Loss: 0.221273 Content Loss: 2.313700
#
# run [4300]:
# Style Loss: 0.219337 Content Loss: 2.292601
#
# run [4350]:
# Style Loss: 0.218836 Content Loss: 2.270540
#
# run [4400]:
# Style Loss: 0.218254 Content Loss: 2.250312
#
# run [4450]:
# Style Loss: 0.217257 Content Loss: 2.232361
#
# run [4500]:
# Style Loss: 0.215976 Content Loss: 2.215402
#
# run [4550]:
# Style Loss: 0.215534 Content Loss: 2.198829
#
# run [4600]:
# Style Loss: 0.215144 Content Loss: 2.184024
#
# run [4650]:
# Style Loss: 0.216283 Content Loss: 2.169215
#
# run [4700]:
# Style Loss: 0.215336 Content Loss: 2.155879
#
# run [4750]:
# Style Loss: 0.214532 Content Loss: 2.143747
#
# run [4800]:
# Style Loss: 0.216256 Content Loss: 2.130579
#
# run [4850]:
# Style Loss: 0.218175 Content Loss: 2.118724
#
# run [4900]:
# Style Loss: 0.213992 Content Loss: 2.109240
#
# run [4950]:
# Style Loss: 0.213302 Content Loss: 2.099220
#
# run [5000]:
# Style Loss: 0.214594 Content Loss: 2.089035
#
# run [5050]:
# Style Loss: 0.215540 Content Loss: 2.079138
#
# run [5100]:
# Style Loss: 0.211921 Content Loss: 2.072091
#
# run [5150]:
# Style Loss: 0.211501 Content Loss: 2.063932
#
# run [5200]:
# Style Loss: 0.211752 Content Loss: 2.054360
#
# run [5250]:
# Style Loss: 0.209042 Content Loss: 2.047202
#
# run [5300]:
# Style Loss: 0.208311 Content Loss: 2.039723
#
# run [5350]:
# Style Loss: 0.207470 Content Loss: 2.032688
#
# run [5400]:
# Style Loss: 0.206202 Content Loss: 2.026367
#
# run [5450]:
# Style Loss: 0.206564 Content Loss: 2.018970
#
# run [5500]:
# Style Loss: 0.206633 Content Loss: 2.012439
#
# run [5550]:
# Style Loss: 0.205767 Content Loss: 2.006271
#
# run [5600]:
# Style Loss: 0.203378 Content Loss: 2.000576
#
# run [5650]:
# Style Loss: 0.203931 Content Loss: 1.994622
#
# run [5700]:
# Style Loss: 0.202561 Content Loss: 1.989464
#
# run [5750]:
# Style Loss: 0.206549 Content Loss: 1.983097
#
# run [5800]:
# Style Loss: 0.204412 Content Loss: 1.978176
#
# run [5850]:
# Style Loss: 0.200092 Content Loss: 1.973697
#
# run [5900]:
# Style Loss: 0.200996 Content Loss: 1.968129
#
# run [5950]:
# Style Loss: 0.201237 Content Loss: 1.962720
#
# run [6000]:
# Style Loss: 0.203257 Content Loss: 1.960685
#
# run [6050]:
# Style Loss: 0.200765 Content Loss: 1.955240
#
# run [6100]:
# Style Loss: 0.197620 Content Loss: 1.952147
#
# run [6150]:
# Style Loss: 0.198678 Content Loss: 1.949110
#
# run [6200]:
# Style Loss: 0.196670 Content Loss: 1.945189
#
# run [6250]:
# Style Loss: 0.198881 Content Loss: 1.941145
#
# run [6300]:
# Style Loss: 0.199336 Content Loss: 1.938299
#
# run [6350]:
# Style Loss: 0.201176 Content Loss: 1.934825
#
# run [6400]:
# Style Loss: 17275.359375 Content Loss: 4.019508
#
# run [6450]:
# Style Loss: 29451648.000000 Content Loss: 113.873131
#
# run [6500]:
# Style Loss: 9936082.000000 Content Loss: 71.388550
#
# run [6550]:
# Style Loss: 209.176849 Content Loss: 5.966622
#
# run [6600]:
# Style Loss: 50.650379 Content Loss: 5.772601
#
# run [6650]:
# Style Loss: 22.207447 Content Loss: 5.582771
#
# run [6700]:
# Style Loss: 11.535242 Content Loss: 5.372637
#
# run [6750]:
# Style Loss: 5.858760 Content Loss: 5.137240
#
# run [6800]:
# Style Loss: 3.137690 Content Loss: 4.868857
#
# run [6850]:
# Style Loss: 1.723715 Content Loss: 4.558966
#
# run [6900]:
# Style Loss: 1.061378 Content Loss: 4.248572
#
# run [6950]:
# Style Loss: 0.743279 Content Loss: 3.955713
#
# run [7000]:
# Style Loss: 0.578221 Content Loss: 3.704463
#
# run [7050]:
# Style Loss: 0.487339 Content Loss: 3.514084
#
# run [7100]:
# Style Loss: 0.427386 Content Loss: 3.357843
#
# run [7150]:
# Style Loss: 0.386550 Content Loss: 3.230958
#
# run [7200]:
# Style Loss: 0.357772 Content Loss: 3.120136
#
# run [7250]:
# Style Loss: 0.337281 Content Loss: 3.031456
#
# run [7300]:
# Style Loss: 0.321695 Content Loss: 2.950277
#
# run [7350]:
# Style Loss: 0.304612 Content Loss: 2.879214
#
# run [7400]:
# Style Loss: 0.295677 Content Loss: 2.816639
#
# run [7450]:
# Style Loss: 0.283638 Content Loss: 2.760728
#
# run [7500]:
# Style Loss: 0.274841 Content Loss: 2.707357
#
# run [7550]:
# Style Loss: 0.266767 Content Loss: 2.661000
#
# run [7600]:
# Style Loss: 0.261971 Content Loss: 2.616746
#
# run [7650]:
# Style Loss: 0.255772 Content Loss: 2.575706
#
# run [7700]:
# Style Loss: 0.251009 Content Loss: 2.538340
#
# run [7750]:
# Style Loss: 0.246908 Content Loss: 2.502659
#
# run [7800]:
# Style Loss: 0.244146 Content Loss: 2.468193
#
# run [7850]:
# Style Loss: 0.241080 Content Loss: 2.437020
#
# run [7900]:
# Style Loss: 0.238450 Content Loss: 2.408562
#
# run [7950]:
# Style Loss: 0.237055 Content Loss: 2.379946
#
# run [8000]:
# Style Loss: 0.232999 Content Loss: 2.356233
#
# run [8050]:
# Style Loss: 0.231136 Content Loss: 2.331774
#
# run [8100]:
# Style Loss: 0.230272 Content Loss: 2.308105
#
# run [8150]:
# Style Loss: 0.229011 Content Loss: 2.286892
#
# run [8200]:
# Style Loss: 0.226689 Content Loss: 2.268958
#
# run [8250]:
# Style Loss: 0.225242 Content Loss: 2.250866
#
# run [8300]:
# Style Loss: 0.223939 Content Loss: 2.234163
#
# run [8350]:
# Style Loss: 0.223102 Content Loss: 2.218267
#
# run [8400]:
# Style Loss: 0.221471 Content Loss: 2.203799
#
# run [8450]:
# Style Loss: 0.220520 Content Loss: 2.188815
#
# run [8500]:
# Style Loss: 0.220319 Content Loss: 2.175235
#
# run [8550]:
# Style Loss: 0.219745 Content Loss: 2.162696
#
# run [8600]:
# Style Loss: 0.218814 Content Loss: 2.150169
#
# run [8650]:
# Style Loss: 0.218433 Content Loss: 2.138516
#
# run [8700]:
# Style Loss: 0.217246 Content Loss: 2.128134
#
# run [8750]:
# Style Loss: 0.216374 Content Loss: 2.118082
#
# run [8800]:
# Style Loss: 0.216187 Content Loss: 2.108494
#
# run [8850]:
# Style Loss: 0.215339 Content Loss: 2.099041
#
# run [8900]:
# Style Loss: 0.215366 Content Loss: 2.089576
#
# run [8950]:
# Style Loss: 0.215268 Content Loss: 2.079941
#
# run [9000]:
# Style Loss: 0.214676 Content Loss: 2.070832
#
# run [9050]:
# Style Loss: 0.214707 Content Loss: 2.061836
#
# run [9100]:
# Style Loss: 0.213426 Content Loss: 2.055021
#
# run [9150]:
# Style Loss: 0.213811 Content Loss: 2.046991
#
# run [9200]:
# Style Loss: 0.212320 Content Loss: 2.039829
#
# run [9250]:
# Style Loss: 0.211813 Content Loss: 2.032625
#
# run [9300]:
# Style Loss: 0.211637 Content Loss: 2.024962
#
# run [9350]:
# Style Loss: 0.212467 Content Loss: 2.017912
#
# run [9400]:
# Style Loss: 0.210879 Content Loss: 2.011707
#
# run [9450]:
# Style Loss: 0.240378 Content Loss: 2.004345
#
# run [9500]:
# Style Loss: 0.207874 Content Loss: 2.000719
#
# run [9550]:
# Style Loss: 0.208212 Content Loss: 1.995259
#
# run [9600]:
# Style Loss: 0.208422 Content Loss: 1.989385
#
# run [9650]:
# Style Loss: 0.216439 Content Loss: 1.983948
#
# run [9700]:
# Style Loss: 0.207747 Content Loss: 1.979877
#
# run [9750]:
# Style Loss: 0.205579 Content Loss: 1.975574
#
# run [9800]:
# Style Loss: 0.205983 Content Loss: 1.970660
#
# run [9850]:
# Style Loss: 0.206712 Content Loss: 1.965689
#
# run [9900]:
# Style Loss: 0.212896 Content Loss: 1.961345
#
# run [9950]:
# Style Loss: 0.205366 Content Loss: 1.958087
#
# run [10000]:
# Style Loss: 0.204215 Content Loss: 1.954309

# %% [markdown]
# ## Step 8: Improve the model with the total-variation regularization
# $$\mathcal{L}_{total-variation} = w\sum_{c=1}^3\biggr(\sum_{i=1}^{H}\sum_{j=1}^{W-1}(x_{i,j+1,c} - x_{i,j,c})^2 + \sum_{i=1}^{H-1}\sum_{j=1}^{W}(x_{i+1,j,c}-x_{i,j,c})^2\biggr)$$
# c is RGB, x_ijc is an element of input image tensor, and (H, W) is a size of an input image.
#
# **Problem 7.** Define the total-variation loss.

# %%
class TotalVariationLoss(nn.Module):
  def __init__(self):
    super(TotalVariationLoss, self).__init__()

  def forward(self, input):
    ################################################################################
    #### TODO: Define the total-variation loss.                                 ####
    #### Input:                                                                 ####
    ####   - input: the image tensors of (a, b, c, d) size, where               ####
    ####            a = batch size (= 1)                                        ####
    ####            b = RGB (= 3)                                               ####
    ####            (c, d) = size of the input image                            ####
    #### Output:                                                                ####
    ####   - input                                                              ####
    ################################################################################

    self.loss = torch.sum((input[:,:,:,:-1] - input[:,:,:,1:]) ** 2) + torch.sum((input[:,:,:-1,:] - input[:,:,1:,:]) ** 2)
    
    ################################################################################
    return input

# %% [markdown]
# **Problem 8.** Define a new merg_image function regarding the total-variation loss.

# %%
def merge_image_with_tv_loss(cnn, content_img, style_img, input_img,
                num_steps, style_weight, content_weight, tv_weight):
  
  # get a transfer model
  old_model, style_losses, content_losses = transfer_model(cnn, style_img, content_img)
  tv_loss = TotalVariationLoss()
  model = nn.Sequential(tv_loss, *old_model)  # add the total-variation loss in the beginning of the model

  #####################################################################################
  #### TODO: Define a new merg_image function regarding the totoal-variation loss. ####
  #####################################################################################


  # get an optimizer
  output_img = input_img.clone()
  optimizer = get_input_optimizer(output_img)

  # start optimizing
  run = [0]
  while run[0] <= num_steps:
    def closure():
      output_img.data.clamp_(0, 1)

      optimizer.zero_grad()
      model(output_img)
      style_score = 0
      content_score = 0
      total_var_score = 0
      for i, sl in enumerate(style_losses):
        style_score += style_weight[i] * sl.loss
      for j, cl in enumerate(content_losses):
        content_score += content_weight[j] * cl.loss
      total_var_score += tv_weight * tv_loss.loss

      loss = style_score + content_score + total_var_score
      loss.backward()

      run[0] += 1
      if run[0] % 50 == 0:
        print(f"run {run}:")
        print(f"Style Loss: {style_score.item():4f} Content Loss: {content_score.item():4f}")
        print(f"Total Varation Loss: {total_var_score:4f}")
        print()

      return style_score + content_score

    optimizer.step(closure)


  output_img.data.clamp_(0, 1)

  ####################################################################################
  del model
  del old_model
  return output_img.cpu()

# %% [markdown]
# **Problem 9 (Optional).** Revise the hyperparameters if you need.

# %%
#######################################################
#### TODO: Revise the hyperparameters if you need. ####
#######################################################
TV_WEIGHT = 0.001
#######################################################

# %%
input_img = content_img.clone()

plt.figure()
imshow(input_img, title='Input Image')

output_img2 = merge_image_with_tv_loss(cnn, content_img, style_img, input_img,
                                      NUM_STEPS, STYLE_WEIGHTS, CONTENT_WEIGHTS, TV_WEIGHT)

plt.figure()
imshow(output_img, title='Output Image without TV')
imshow(output_img2, title='Output Image with TV', save=gdrive_data+'/tv_loss.jpg')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """
# run [50]:
# Style Loss: 62.823391 Content Loss: 1.865011
# Total Varation Loss: 0.849454
#
# run [100]:
# Style Loss: 22.168528 Content Loss: 2.545539
# Total Varation Loss: 0.910108
#
# run [150]:
# Style Loss: 10.507986 Content Loss: 2.766925
# Total Varation Loss: 0.908433
#
# run [200]:
# Style Loss: 5.083801 Content Loss: 2.894387
# Total Varation Loss: 0.890858
#
# run [250]:
# Style Loss: 3.037161 Content Loss: 2.833121
# Total Varation Loss: 0.836105
#
# run [300]:
# Style Loss: 1.889017 Content Loss: 2.688666
# Total Varation Loss: 0.783974
#
# run [350]:
# Style Loss: 1.208317 Content Loss: 2.572040
# Total Varation Loss: 0.750953
#
# run [400]:
# Style Loss: 0.817202 Content Loss: 2.483209
# Total Varation Loss: 0.728830
#
# run [450]:
# Style Loss: 0.594238 Content Loss: 2.411039
# Total Varation Loss: 0.710435
#
# run [500]:
# Style Loss: 0.471095 Content Loss: 2.348834
# Total Varation Loss: 0.698002
#
# run [550]:
# Style Loss: 0.392627 Content Loss: 2.294241
# Total Varation Loss: 0.687477
#
# run [600]:
# Style Loss: 0.343010 Content Loss: 2.245319
# Total Varation Loss: 0.679877
#
# run [650]:
# Style Loss: 0.309360 Content Loss: 2.206953
# Total Varation Loss: 0.675136
#
# run [700]:
# Style Loss: 0.286274 Content Loss: 2.175599
# Total Varation Loss: 0.671948
#
# run [750]:
# Style Loss: 0.267250 Content Loss: 2.148762
# Total Varation Loss: 0.669075
#
# run [800]:
# Style Loss: 0.254983 Content Loss: 2.126007
# Total Varation Loss: 0.666927
#
# run [850]:
# Style Loss: 0.245046 Content Loss: 2.105641
# Total Varation Loss: 0.665519
#
# run [900]:
# Style Loss: 0.236875 Content Loss: 2.089420
# Total Varation Loss: 0.664330
#
# run [950]:
# Style Loss: 0.230472 Content Loss: 2.074148
# Total Varation Loss: 0.663108
#
# run [1000]:
# Style Loss: 0.225397 Content Loss: 2.060696
# Total Varation Loss: 0.662181
#
# run [1050]:
# Style Loss: 0.220638 Content Loss: 2.049387
# Total Varation Loss: 0.661561
#
# run [1100]:
# Style Loss: 0.216958 Content Loss: 2.040164
# Total Varation Loss: 0.660914
#
# run [1150]:
# Style Loss: 0.213702 Content Loss: 2.032183
# Total Varation Loss: 0.660611
#
# run [1200]:
# Style Loss: 0.210804 Content Loss: 2.024701
# Total Varation Loss: 0.660165
#
# run [1250]:
# Style Loss: 0.208834 Content Loss: 2.018152
# Total Varation Loss: 0.659777
#
# run [1300]:
# Style Loss: 0.206550 Content Loss: 2.012717
# Total Varation Loss: 0.659480
#
# run [1350]:
# Style Loss: 0.204618 Content Loss: 2.008156
# Total Varation Loss: 0.659090
#
# run [1400]:
# Style Loss: 0.202934 Content Loss: 2.003759
# Total Varation Loss: 0.658804
#
# run [1450]:
# Style Loss: 0.201801 Content Loss: 1.999850
# Total Varation Loss: 0.658525
#
# run [1500]:
# Style Loss: 0.201535 Content Loss: 1.996021
# Total Varation Loss: 0.658456
#
# run [1550]:
# Style Loss: 0.199141 Content Loss: 1.993072
# Total Varation Loss: 0.658212
#
# run [1600]:
# Style Loss: 0.197681 Content Loss: 1.990123
# Total Varation Loss: 0.657922
#
# run [1650]:
# Style Loss: 0.201853 Content Loss: 1.987503
# Total Varation Loss: 0.658160
#
# run [1700]:
# Style Loss: 0.196800 Content Loss: 1.985627
# Total Varation Loss: 0.657956
#
# run [1750]:
# Style Loss: 0.194481 Content Loss: 1.983225
# Total Varation Loss: 0.657462
#
# run [1800]:
# Style Loss: 0.194207 Content Loss: 1.982386
# Total Varation Loss: 0.657833
#
# run [1850]:
# Style Loss: 0.193224 Content Loss: 1.980193
# Total Varation Loss: 0.657339
#
# run [1900]:
# Style Loss: 0.193244 Content Loss: 1.978137
# Total Varation Loss: 0.656945
#
# run [1950]:
# Style Loss: 0.195261 Content Loss: 1.976818
# Total Varation Loss: 0.656727
#
# run [2000]:
# Style Loss: 0.193469 Content Loss: 1.976062
# Total Varation Loss: 0.656907
#
# run [2050]:
# Style Loss: 0.190767 Content Loss: 1.974431
# Total Varation Loss: 0.656422
#
# run [2100]:
# Style Loss: 0.190282 Content Loss: 1.973453
# Total Varation Loss: 0.656314
#
# run [2150]:
# Style Loss: 0.190095 Content Loss: 1.973071
# Total Varation Loss: 0.656451
#
# run [2200]:
# Style Loss: 0.189503 Content Loss: 1.971910
# Total Varation Loss: 0.656399
#
# run [2250]:
# Style Loss: 0.190006 Content Loss: 1.971979
# Total Varation Loss: 0.656636
#
# run [2300]:
# Style Loss: 28660792.000000 Content Loss: 113.479240
# Total Varation Loss: 148.964951
#
# run [2350]:
# Style Loss: 32535476.000000 Content Loss: 119.664856
# Total Varation Loss: 139.068283
#
# run [2400]:
# Style Loss: 1041.215088 Content Loss: 6.614857
# Total Varation Loss: 9.672180
#
# run [2450]:
# Style Loss: 102.315514 Content Loss: 6.079995
# Total Varation Loss: 6.934312
#
# run [2500]:
# Style Loss: 32.734005 Content Loss: 5.908744
# Total Varation Loss: 4.770346
#
# run [2550]:
# Style Loss: 18.763636 Content Loss: 5.734552
# Total Varation Loss: 3.061797
#
# run [2600]:
# Style Loss: 10.882305 Content Loss: 5.524265
# Total Varation Loss: 1.746478
#
# run [2650]:
# Style Loss: 6.123491 Content Loss: 5.283541
# Total Varation Loss: 1.175355
#
# run [2700]:
# Style Loss: 3.394075 Content Loss: 5.020745
# Total Varation Loss: 1.011116
#
# run [2750]:
# Style Loss: 1.952826 Content Loss: 4.745285
# Total Varation Loss: 0.944720
#
# run [2800]:
# Style Loss: 1.212651 Content Loss: 4.459470
# Total Varation Loss: 0.855533
#
# run [2850]:
# Style Loss: 0.841236 Content Loss: 4.200367
# Total Varation Loss: 0.770639
#
# run [2900]:
# Style Loss: 0.636368 Content Loss: 3.992276
# Total Varation Loss: 0.721944
#
# run [2950]:
# Style Loss: 0.513698 Content Loss: 3.816412
# Total Varation Loss: 0.701335
#
# run [3000]:
# Style Loss: 0.435148 Content Loss: 3.675007
# Total Varation Loss: 0.693141
#
# run [3050]:
# Style Loss: 0.386108 Content Loss: 3.553358
# Total Varation Loss: 0.686392
#
# run [3100]:
# Style Loss: 0.349234 Content Loss: 3.448249
# Total Varation Loss: 0.680345
#
# run [3150]:
# Style Loss: 0.323909 Content Loss: 3.352552
# Total Varation Loss: 0.675806
#
# run [3200]:
# Style Loss: 0.304074 Content Loss: 3.263224
# Total Varation Loss: 0.674306
#
# run [3250]:
# Style Loss: 0.287161 Content Loss: 3.181705
# Total Varation Loss: 0.672960
#
# run [3300]:
# Style Loss: 0.273922 Content Loss: 3.110111
# Total Varation Loss: 0.670540
#
# run [3350]:
# Style Loss: 0.265199 Content Loss: 3.042040
# Total Varation Loss: 0.668090
#
# run [3400]:
# Style Loss: 0.256826 Content Loss: 2.985153
# Total Varation Loss: 0.667062
#
# run [3450]:
# Style Loss: 0.248077 Content Loss: 2.929705
# Total Varation Loss: 0.666221
#
# run [3500]:
# Style Loss: 0.243506 Content Loss: 2.880175
# Total Varation Loss: 0.665205
#
# run [3550]:
# Style Loss: 0.241858 Content Loss: 2.831730
# Total Varation Loss: 0.664542
#
# run [3600]:
# Style Loss: 0.234495 Content Loss: 2.790815
# Total Varation Loss: 0.663936
#
# run [3650]:
# Style Loss: 0.231577 Content Loss: 2.750102
# Total Varation Loss: 0.663307
#
# run [3700]:
# Style Loss: 0.228699 Content Loss: 2.712480
# Total Varation Loss: 0.662703
#
# run [3750]:
# Style Loss: 0.225925 Content Loss: 2.678164
# Total Varation Loss: 0.662300
#
# run [3800]:
# Style Loss: 0.223322 Content Loss: 2.645162
# Total Varation Loss: 0.661857
#
# run [3850]:
# Style Loss: 0.222705 Content Loss: 2.613770
# Total Varation Loss: 0.661757
#
# run [3900]:
# Style Loss: 0.221514 Content Loss: 2.585164
# Total Varation Loss: 0.661648
#
# run [3950]:
# Style Loss: 0.216421 Content Loss: 2.557715
# Total Varation Loss: 0.661227
#
# run [4000]:
# Style Loss: 0.216055 Content Loss: 2.529468
# Total Varation Loss: 0.660703
#
# run [4050]:
# Style Loss: 0.215072 Content Loss: 2.503936
# Total Varation Loss: 0.660621
#
# run [4100]:
# Style Loss: 0.214305 Content Loss: 2.478243
# Total Varation Loss: 0.660394
#
# run [4150]:
# Style Loss: 0.213765 Content Loss: 2.455290
# Total Varation Loss: 0.659751
#
# run [4200]:
# Style Loss: 0.212147 Content Loss: 2.432514
# Total Varation Loss: 0.659744
#
# run [4250]:
# Style Loss: 0.209644 Content Loss: 2.412059
# Total Varation Loss: 0.659444
#
# run [4300]:
# Style Loss: 0.208746 Content Loss: 2.392903
# Total Varation Loss: 0.659201
#
# run [4350]:
# Style Loss: 0.207438 Content Loss: 2.374459
# Total Varation Loss: 0.658718
#
# run [4400]:
# Style Loss: 0.209250 Content Loss: 2.353736
# Total Varation Loss: 0.658212
#
# run [4450]:
# Style Loss: 0.205857 Content Loss: 2.335525
# Total Varation Loss: 0.658142
#
# run [4500]:
# Style Loss: 0.205402 Content Loss: 2.317705
# Total Varation Loss: 0.657666
#
# run [4550]:
# Style Loss: 0.203669 Content Loss: 2.302520
# Total Varation Loss: 0.657415
#
# run [4600]:
# Style Loss: 0.202392 Content Loss: 2.287951
# Total Varation Loss: 0.657147
#
# run [4650]:
# Style Loss: 0.202230 Content Loss: 2.272428
# Total Varation Loss: 0.657117
#
# run [4700]:
# Style Loss: 0.201104 Content Loss: 2.258691
# Total Varation Loss: 0.656711
#
# run [4750]:
# Style Loss: 0.201281 Content Loss: 2.244723
# Total Varation Loss: 0.657118
#
# run [4800]:
# Style Loss: 0.202857 Content Loss: 2.231934
# Total Varation Loss: 0.657207
#
# run [4850]:
# Style Loss: 0.199137 Content Loss: 2.222222
# Total Varation Loss: 0.656776
#
# run [4900]:
# Style Loss: 0.198489 Content Loss: 2.211361
# Total Varation Loss: 0.656730
#
# run [4950]:
# Style Loss: 0.197917 Content Loss: 2.200152
# Total Varation Loss: 0.656872
#
# run [5000]:
# Style Loss: 0.197896 Content Loss: 2.189406
# Total Varation Loss: 0.656648
#
# run [5050]:
# Style Loss: 0.198018 Content Loss: 2.179620
# Total Varation Loss: 0.656791
#
# run [5100]:
# Style Loss: 0.198698 Content Loss: 2.169637
# Total Varation Loss: 0.656980
#
# run [5150]:
# Style Loss: 0.198509 Content Loss: 2.160082
# Total Varation Loss: 0.657124
#
# run [5200]:
# Style Loss: 0.197980 Content Loss: 2.151513
# Total Varation Loss: 0.657125
#
# run [5250]:
# Style Loss: 0.197277 Content Loss: 2.143674
# Total Varation Loss: 0.657313
#
# run [5300]:
# Style Loss: 0.196417 Content Loss: 2.135698
# Total Varation Loss: 0.657517
#
# run [5350]:
# Style Loss: 0.195661 Content Loss: 2.128558
# Total Varation Loss: 0.657804
#
# run [5400]:
# Style Loss: 0.197987 Content Loss: 2.120164
# Total Varation Loss: 0.657970
#
# run [5450]:
# Style Loss: 0.195493 Content Loss: 2.113804
# Total Varation Loss: 0.658151
#
# run [5500]:
# Style Loss: 0.193960 Content Loss: 2.106527
# Total Varation Loss: 0.658035
#
# run [5550]:
# Style Loss: 0.193316 Content Loss: 2.099899
# Total Varation Loss: 0.657904
#
# run [5600]:
# Style Loss: 0.193010 Content Loss: 2.093004
# Total Varation Loss: 0.657682
#
# run [5650]:
# Style Loss: 0.197231 Content Loss: 2.086592
# Total Varation Loss: 0.657584
#
# run [5700]:
# Style Loss: 0.192163 Content Loss: 2.080894
# Total Varation Loss: 0.657619
#
# run [5750]:
# Style Loss: 0.191700 Content Loss: 2.075056
# Total Varation Loss: 0.657556
#
# run [5800]:
# Style Loss: 0.192150 Content Loss: 2.068563
# Total Varation Loss: 0.657545
#
# run [5850]:
# Style Loss: 0.191843 Content Loss: 2.062857
# Total Varation Loss: 0.657430
#
# run [5900]:
# Style Loss: 0.194244 Content Loss: 2.056801
# Total Varation Loss: 0.657934
#
# run [5950]:
# Style Loss: 0.192180 Content Loss: 2.051754
# Total Varation Loss: 0.657664
#
# run [6000]:
# Style Loss: 0.192116 Content Loss: 2.046627
# Total Varation Loss: 0.657531
#
# run [6050]:
# Style Loss: 0.190892 Content Loss: 2.042120
# Total Varation Loss: 0.657365
#
# run [6100]:
# Style Loss: 0.198262 Content Loss: 2.041210
# Total Varation Loss: 0.659890
#
# run [6150]:
# Style Loss: 0.191202 Content Loss: 2.033888
# Total Varation Loss: 0.657083
#
# run [6200]:
# Style Loss: 0.190026 Content Loss: 2.029697
# Total Varation Loss: 0.656909
#
# run [6250]:
# Style Loss: 0.192378 Content Loss: 2.025672
# Total Varation Loss: 0.656919
#
# run [6300]:
# Style Loss: 0.190022 Content Loss: 2.022540
# Total Varation Loss: 0.656971
#
# run [6350]:
# Style Loss: 0.191388 Content Loss: 2.020488
# Total Varation Loss: 0.657806
#
# run [6400]:
# Style Loss: 0.189740 Content Loss: 2.015643
# Total Varation Loss: 0.657037
#
# run [6450]:
# Style Loss: 0.192227 Content Loss: 2.012500
# Total Varation Loss: 0.657170
#
# run [6500]:
# Style Loss: 0.212722 Content Loss: 2.016868
# Total Varation Loss: 0.661023
#
# run [6550]:
# Style Loss: 0.190365 Content Loss: 2.010355
# Total Varation Loss: 0.658004
#
# run [6600]:
# Style Loss: 0.200798 Content Loss: 2.003844
# Total Varation Loss: 0.656177
#
# run [6650]:
# Style Loss: 0.188606 Content Loss: 2.001313
# Total Varation Loss: 0.656125
#
# run [6700]:
# Style Loss: 0.188923 Content Loss: 1.999095
# Total Varation Loss: 0.656188
#
# run [6750]:
# Style Loss: 0.188701 Content Loss: 1.996936
# Total Varation Loss: 0.656258
#
# run [6800]:
# Style Loss: 0.189954 Content Loss: 1.994820
# Total Varation Loss: 0.656737
#
# run [6850]:
# Style Loss: 0.188770 Content Loss: 1.991163
# Total Varation Loss: 0.656075
#
# run [6900]:
# Style Loss: 0.189526 Content Loss: 1.988418
# Total Varation Loss: 0.656179
#
# run [6950]:
# Style Loss: 0.194900 Content Loss: 1.986933
# Total Varation Loss: 0.657006
#
# run [7000]:
# Style Loss: 0.193091 Content Loss: 1.984347
# Total Varation Loss: 0.656607
#
# run [7050]:
# Style Loss: 0.193191 Content Loss: 1.983523
# Total Varation Loss: 0.656978
#
# run [7100]:
# Style Loss: 0.190086 Content Loss: 1.982282
# Total Varation Loss: 0.657041
#
# run [7150]:
# Style Loss: 0.196591 Content Loss: 1.983020
# Total Varation Loss: 0.657872
#
# run [7200]:
# Style Loss: 0.353449 Content Loss: 1.985597
# Total Varation Loss: 0.659995
#
# run [7250]:
# Style Loss: 0.191439 Content Loss: 1.981970
# Total Varation Loss: 0.657976
#
# run [7300]:
# Style Loss: 0.243751 Content Loss: 1.980108
# Total Varation Loss: 0.657656
#
# run [7350]:
# Style Loss: 0.192057 Content Loss: 1.978633
# Total Varation Loss: 0.657209
#
# run [7400]:
# Style Loss: 34706992.000000 Content Loss: 125.493973
# Total Varation Loss: 147.887909
#
# run [7450]:
# Style Loss: 10555260.000000 Content Loss: 72.846008
# Total Varation Loss: 71.045959
#
# run [7500]:
# Style Loss: 176.242538 Content Loss: 5.801684
# Total Varation Loss: 8.001274
#
# run [7550]:
# Style Loss: 52.934498 Content Loss: 5.799447
# Total Varation Loss: 5.824859
#
# run [7600]:
# Style Loss: 23.573521 Content Loss: 5.678360
# Total Varation Loss: 3.876920
#
# run [7650]:
# Style Loss: 12.929275 Content Loss: 5.509742
# Total Varation Loss: 2.319304
#
# run [7700]:
# Style Loss: 7.587211 Content Loss: 5.297392
# Total Varation Loss: 1.446422
#
# run [7750]:
# Style Loss: 4.362781 Content Loss: 5.041280
# Total Varation Loss: 1.060323
#
# run [7800]:
# Style Loss: 2.607204 Content Loss: 4.750678
# Total Varation Loss: 0.940211
#
# run [7850]:
# Style Loss: 1.568018 Content Loss: 4.444751
# Total Varation Loss: 0.874810
#
# run [7900]:
# Style Loss: 1.084708 Content Loss: 4.149172
# Total Varation Loss: 0.802891
#
# run [7950]:
# Style Loss: 0.804596 Content Loss: 3.890627
# Total Varation Loss: 0.743794
#
# run [8000]:
# Style Loss: 0.639984 Content Loss: 3.693870
# Total Varation Loss: 0.714063
#
# run [8050]:
# Style Loss: 0.533358 Content Loss: 3.532117
# Total Varation Loss: 0.700982
#
# run [8100]:
# Style Loss: 0.462305 Content Loss: 3.396862
# Total Varation Loss: 0.692386
#
# run [8150]:
# Style Loss: 0.411331 Content Loss: 3.280794
# Total Varation Loss: 0.685383
#
# run [8200]:
# Style Loss: 0.374300 Content Loss: 3.177297
# Total Varation Loss: 0.679683
#
# run [8250]:
# Style Loss: 0.346051 Content Loss: 3.085038
# Total Varation Loss: 0.675712
#
# run [8300]:
# Style Loss: 0.321395 Content Loss: 3.005239
# Total Varation Loss: 0.673782
#
# run [8350]:
# Style Loss: 0.302448 Content Loss: 2.930872
# Total Varation Loss: 0.671467
#
# run [8400]:
# Style Loss: 0.287266 Content Loss: 2.861882
# Total Varation Loss: 0.669168
#
# run [8450]:
# Style Loss: 0.275296 Content Loss: 2.801056
# Total Varation Loss: 0.667527
#
# run [8500]:
# Style Loss: 0.265618 Content Loss: 2.748163
# Total Varation Loss: 0.666418
#
# run [8550]:
# Style Loss: 0.258955 Content Loss: 2.696438
# Total Varation Loss: 0.665427
#
# run [8600]:
# Style Loss: 0.252658 Content Loss: 2.649335
# Total Varation Loss: 0.664670
#
# run [8650]:
# Style Loss: 0.247317 Content Loss: 2.606048
# Total Varation Loss: 0.663756
#
# run [8700]:
# Style Loss: 0.243138 Content Loss: 2.564180
# Total Varation Loss: 0.662839
#
# run [8750]:
# Style Loss: 0.239098 Content Loss: 2.527114
# Total Varation Loss: 0.662135
#
# run [8800]:
# Style Loss: 0.237379 Content Loss: 2.491414
# Total Varation Loss: 0.661457
#
# run [8850]:
# Style Loss: 0.235370 Content Loss: 2.456681
# Total Varation Loss: 0.661274
#
# run [8900]:
# Style Loss: 0.232106 Content Loss: 2.425910
# Total Varation Loss: 0.660880
#
# run [8950]:
# Style Loss: 0.229447 Content Loss: 2.395729
# Total Varation Loss: 0.660683
#
# run [9000]:
# Style Loss: 0.227814 Content Loss: 2.367683
# Total Varation Loss: 0.660340
#
# run [9050]:
# Style Loss: 0.225586 Content Loss: 2.341099
# Total Varation Loss: 0.660034
#
# run [9100]:
# Style Loss: 0.223650 Content Loss: 2.316791
# Total Varation Loss: 0.659457
#
# run [9150]:
# Style Loss: 0.221768 Content Loss: 2.295224
# Total Varation Loss: 0.659025
#
# run [9200]:
# Style Loss: 0.220777 Content Loss: 2.273172
# Total Varation Loss: 0.659134
#
# run [9250]:
# Style Loss: 0.219084 Content Loss: 2.254302
# Total Varation Loss: 0.658933
#
# run [9300]:
# Style Loss: 0.217595 Content Loss: 2.235425
# Total Varation Loss: 0.658756
#
# run [9350]:
# Style Loss: 0.217094 Content Loss: 2.218039
# Total Varation Loss: 0.658447
#
# run [9400]:
# Style Loss: 0.216302 Content Loss: 2.200860
# Total Varation Loss: 0.658514
#
# run [9450]:
# Style Loss: 0.216573 Content Loss: 2.185189
# Total Varation Loss: 0.658393
#
# run [9500]:
# Style Loss: 0.214998 Content Loss: 2.170866
# Total Varation Loss: 0.658464
#
# run [9550]:
# Style Loss: 0.214193 Content Loss: 2.157350
# Total Varation Loss: 0.658404
#
# run [9600]:
# Style Loss: 0.214009 Content Loss: 2.144441
# Total Varation Loss: 0.658628
#
# run [9650]:
# Style Loss: 0.213301 Content Loss: 2.133881
# Total Varation Loss: 0.658471
#
# run [9700]:
# Style Loss: 0.212362 Content Loss: 2.123778
# Total Varation Loss: 0.658739
#
# run [9750]:
# Style Loss: 0.211480 Content Loss: 2.114644
# Total Varation Loss: 0.658618
#
# run [9800]:
# Style Loss: 0.210674 Content Loss: 2.106048
# Total Varation Loss: 0.658692
#
# run [9850]:
# Style Loss: 0.210539 Content Loss: 2.097929
# Total Varation Loss: 0.658787
#
# run [9900]:
# Style Loss: 0.209406 Content Loss: 2.090592
# Total Varation Loss: 0.658818
#
# run [9950]:
# Style Loss: 0.208148 Content Loss: 2.084025
# Total Varation Loss: 0.658569
#
# run [10000]:
# Style Loss: 0.207479 Content Loss: 2.076941
# Total Varation Loss: 0.658519

# %% [markdown]
# ## Step 9: Fast neural style transfer with perceptual loss.
# Refer to the paper, [Perceptual Losses for Real-Time Style Transfer and Super-Resolution](https://cs.stanford.edu/people/jcjohns/papers/eccv16/JohnsonECCV16.pdf)
#
# The previous neural style transfer model merged the content and style images through the optimization so that we had to retrain if the content image is changed.
#
# In this paper, the authors suggested a method that exploits an input image passed through a network called Image Transform Net.
# ![Fast neural style transfer](https://hoya012.github.io/assets/img/fast_style_transfer/1.PNG)

# %% [markdown]
# ### Download the COCO dataset

# %%
import os
import urllib
import zipfile

if os.path.isdir("./val2017"):
  print("Dataset is already downloaded")
else:
  urllib.request.urlretrieve("http://images.cocodataset.org/zips/val2017.zip", "val2017.zip")
  val2017 = zipfile.ZipFile('./val2017.zip')
  val2017.extractall('.')
  val2017.close()
  print("COCO dataset is downloaded")
# Out:
# Dataset is already downloaded

# %% [markdown]
# ### Load the dataset

# %%
BATCH_SIZE = 4

# %%
train_dataset = datasets.ImageFolder(".", preprocess)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=BATCH_SIZE)

# %%
style_img = image_loader("./style.jpg", batch_size=BATCH_SIZE)
content_img = image_loader("./content.jpg", batch_size=BATCH_SIZE)

plt.figure()
imshow(style_img[0], title='Style Image')

plt.figure()
imshow(content_img[0], title='Content Image')

# %% [markdown]
# ### Define the Image Transform Net

# %%
class ConvLayer(nn.Module):
  def __init__(self, in_channels, out_channels, kernel_size, stride):
    super(ConvLayer, self).__init__()
    reflection_padding = kernel_size // 2
    self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
    self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

  def forward(self, x):
    out = self.reflection_pad(x)
    out = self.conv2d(out)
    return out

# %%
class ResidualBlock(nn.Module):
  """ResidualBlock
  introduced in: https://arxiv.org/abs/1512.03385
  recommended architecture: http://torch.ch/blog/2016/02/04/resnets.html
  """

  def __init__(self, channels):
    super(ResidualBlock, self).__init__()
    self.conv1 = ConvLayer(channels, channels, kernel_size=3, stride=1)
    self.in1 = nn.InstanceNorm2d(channels, affine=True)
    self.conv2 = ConvLayer(channels, channels, kernel_size=3, stride=1)
    self.in2 = nn.InstanceNorm2d(channels, affine=True)
    self.relu = nn.ReLU()

  def forward(self, x):
    residual = x
    out = self.relu(self.in1(self.conv1(x)))
    out = self.in2(self.conv2(out))
    out = out + residual
    return out

# %%
class UpsampleConvLayer(nn.Module):
  """UpsampleConvLayer
  Upsamples the input and then does a convolution. This method gives better results
  compared to ConvTranspose2d.
  ref: http://distill.pub/2016/deconv-checkerboard/
  """

  def __init__(self, in_channels, out_channels, kernel_size, stride, upsample=None):
    super(UpsampleConvLayer, self).__init__()
    self.upsample = upsample
    reflection_padding = kernel_size // 2
    self.reflection_pad = nn.ReflectionPad2d(reflection_padding)
    self.conv2d = nn.Conv2d(in_channels, out_channels, kernel_size, stride)

  def forward(self, x):
    x_in = x
    if self.upsample:
      x_in = nn.functional.interpolate(x_in, mode='nearest', scale_factor=self.upsample)
    out = self.reflection_pad(x_in)
    out = self.conv2d(out)
    return out

# %%
class TransformerNet(nn.Module):
  def __init__(self):
    super(TransformerNet, self).__init__()
    # Initial convolution layers
    self.encoder = nn.Sequential()
    
    self.encoder.add_module('conv1', ConvLayer(3, 32, kernel_size=9, stride=1))
    self.encoder.add_module('in1', nn.InstanceNorm2d(32, affine=True))
    self.encoder.add_module('relu1', nn.ReLU())
    
    self.encoder.add_module('conv2', ConvLayer(32, 64, kernel_size=3, stride=2))
    self.encoder.add_module('in2', nn.InstanceNorm2d(64, affine=True))
    self.encoder.add_module('relu2', nn.ReLU())
    
    self.encoder.add_module('conv3', ConvLayer(64, 128, kernel_size=3, stride=2))
    self.encoder.add_module('in3', nn.InstanceNorm2d(128, affine=True))
    self.encoder.add_module('relu3', nn.ReLU())

    # Residual layers
    self.residual = nn.Sequential()
    
    for i in range(5):
      self.residual.add_module('resblock_%d' %(i+1), ResidualBlock(128))
    
    # Upsampling Layers
    self.decoder = nn.Sequential()
    self.decoder.add_module('deconv1', UpsampleConvLayer(128, 64, kernel_size=3, stride=1, upsample=2))
    self.decoder.add_module('in4', nn.InstanceNorm2d(64, affine=True))
    self.encoder.add_module('relu4', nn.ReLU())

    self.decoder.add_module('deconv2', UpsampleConvLayer(64, 32, kernel_size=3, stride=1, upsample=2))
    self.decoder.add_module('in5', nn.InstanceNorm2d(32, affine=True))
    self.encoder.add_module('relu5', nn.ReLU())

    self.decoder.add_module('deconv3', ConvLayer(32, 3, kernel_size=9, stride=1))

  def forward(self, x):
    encoder_output = self.encoder(x)
    residual_output = self.residual(encoder_output)
    decoder_output = self.decoder(residual_output)
    
    return decoder_output

# %% [markdown]
# **Problem 10.** Complete the fast neural network model using the given networks and data loader above. You should implement both **"saving the trained model parameters (checkpoints)"** and **"loading the trained model parameters and evaluate the model"** to get full points.

# %%
######################################################################################################
#### TODO: Complete the fast neural network model using the given networks and data loader above. ####
####       You should implement both "saving the trained model parameters (checkpoints)"          ####
####       and "loading the trained model parameters and evaluate the model"                      ####
####       to get full points.                                                                    ####
######################################################################################################

# %%
######################################################################################################
